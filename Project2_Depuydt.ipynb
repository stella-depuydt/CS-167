# %% [markdown]
# <a href="https://colab.research.google.com/github/stella-depuydt/CS-167/blob/main/Project2_Depuydt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project #2
# ##Name: Stella Depuydt
#
# Proposed Points (out of 25):

# %% [markdown]
# # 1. Problem
# State the problem you are trying to solve with this machine learning experiment. Include a description of the data, where you got the data, and what you're trying to predict..

# %% [markdown]
# The data I'm using for this project came from the Goodreads-books dataset found on Kaggle. I chose this dataet because I like reading and thought I would enjoy working with data related to books and their ratings. Creator of this dataset, Soumik scraped the data via the Goodreads API.
#
# **My research question for this project is to predict which variable most significntly predicts the rating a book recieves.**
#
# The target variable is average rating. The predictor variables are title, authors, (isbn, isbn-13), language code, number of pages, ratings count, and text reviews count. Since the variables being analyzed are numerical (not categorical) variables, this is a regression problem.

# %% [markdown]
# # 2. Data Preparation
# Explain your data preparation. What did you have to do to get your data in shape for your experiments? Why are you certain that you data is clean and prepared for use in your algorithms?

# %% [markdown]
# After I loaded in my data, I checked for missing values. Then I removed both isbn columns because really they aren't as user friendly as the book titles, but they serve the same purpose of identification. I also dropped the book ID number since ID numbers starting at zero are automatically assigned.

# %%
# load and prepare your data here
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')


books_data = pd.read_csv('/content/drive/MyDrive/Datasets/book.csv')
books_data.head(20)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     bookID                                              title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5        9  Unauthorized Harry Potter Book Seven News: "Ha...
# 6       10       Harry Potter Collection (Harry Potter  #1-6)
# 7       12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8       13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# 9       14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10      16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 11      18  The Ultimate Hitchhiker's Guide (Hitchhiker's ...
# ...

# %%
books_data.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
books_data.isna().any()
# Out:
# bookID                False
# title                 False
# authors               False
# average_rating        False
# isbn                  False
# isbn13                False
# language_code         False
# num_pages             False
# ratings_count         False
# text_reviews_count    False
# publication_date      False
# publisher             False
# dtype: bool

# %%
books_data = books_data[['average_rating', 'title', 'authors', 'language_code', 'num_pages', 'ratings_count', 'text_reviews_count', 'publication_date', 'publisher']]
books_data.head()
# Out:
#   average_rating                                              title  \
# 0           4.57  Harry Potter and the Half-Blood Prince (Harry ...
# 1           4.49  Harry Potter and the Order of the Phoenix (Har...
# 2           4.42  Harry Potter and the Chamber of Secrets (Harry...
# 3           4.56  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           4.78  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors language_code num_pages  ratings_count  \
# 0  J.K. Rowling/Mary GrandPré           eng       652        2095690
# 1  J.K. Rowling/Mary GrandPré           eng       870        2153167
# 2                J.K. Rowling           eng       352           6333
# 3  J.K. Rowling/Mary GrandPré           eng       435        2339585
# 4  J.K. Rowling/Mary GrandPré           eng      2690          41428
#
#    text_reviews_count publication_date        publisher
# 0               27591        9/16/2006  Scholastic Inc.
# ...

# %%
import sklearn
import pandas
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor




target= ['average_rating']
predictors = ['title', 'authors','language_code', 'num_pages', 'ratings_count', 'text_reviews_count', 'publication_date', 'publisher']
train_data, test_data, train_sln, test_sln = train_test_split(books_data[predictors], books_data[target])
train_data.head()
# Out:
#                                                   title  \
# 1568                                       Dragon's Eye
# 9892  Black Like Us: A Century of Lesbian  Gay  and ...
# 9818                                            The Key
# 3615                        The Bible Cure For Diabetes
# 2327  The Jefferson Bible: The Life and Morals of Je...
#
#                                                 authors language_code  \
# 1568  Christopher Stasheff/William R. Forstchen/Nick...         en-GB
# 9892  Devon W. Carbado/Evelyn C. White/Dwight A. McB...           eng
# 9818                                       Lynsay Sands           eng
# 3615                                        Don Colbert           eng
# 2327                                   Thomas Jefferson           eng
#
#      num_pages  ratings_count  text_reviews_count publication_date  \
# 1568       279             41                   7         7/1/1994
# 9892       600            127                  16        5/28/2002
# ...

# %%
print(books_data.dtypes)
# Out:
# average_rating        object
# title                 object
# authors               object
# language_code         object
# num_pages             object
# ratings_count          int64
# text_reviews_count     int64
# publication_date      object
# publisher             object
# dtype: object

# %%
books_data['average_rating'] = books_data['average_rating'].apply(lambda x: float(x.split()[0].replace('$', '')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-12d265588571> in <module>
# ----> 1 books_data['average_rating'] = books_data['average_rating'].apply(lambda x: float(x.split()[0].replace('$', '')))
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(train_data)
train_data_normalized = scaler.transform(train_data)
test_data_normalized = scaler.transform(test_data)
train_data_normalized
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-dc2b02cf19f5> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 scaler.fit(train_data)
#       4 train_data_normalized = scaler.transform(train_data)
#       5 test_data_normalized = scaler.transform(test_data)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# ...

# %% [markdown]
# # 3. Research
#
# Put your code and your experiments here.

# %%
# code goes here... don't forget to include graphs. Professor Urness loves graphs.

# %% [markdown]
# #4. Analysis
#
# What did you discover? What insights/recommendations do you have? What did you find that was interesting? Which model was your best model, which models didn't work well? Why do you think this is? In general, I want a discussion of your experiment, the results, and what they mean.

# %% [markdown]
# *your answer here*

# %% [markdown]
# # 5. Bumps in the Road
# What challenges did you encounter? How did you overcome these challenges?

# %% [markdown]
# The first problem I had was when I tried to load in the data. I got an error message that said "Error tokenizing data. C error: Expected 12 fields in line 3350, saw 13." After a google search to figure out what this meant, I opened the data, found and fixed the problem, then reloaded the data.
#
# When I was trying to normlize the data, I had trouble with needin to convert string data to float. I used this website to try to fix the issue, but I couldn't figure it out, so I'm going to switch to the avocado dataset because all the values there are numbers and I will hopefully not run into this issue.
# https://www.statology.org/pandas-could-not-convert-string-to-float/
